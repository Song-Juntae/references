# %%
import os
import re

from collections import Counter

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

font_path = '/usr/share/fonts/truetype/nanum/NanumGothic.ttf'
fm.fontManager.addfont(font_path)
font_name = fm.FontProperties(fname=font_path).get_name()
plt.rcParams['font.family'] = font_name
plt.rcParams['axes.unicode_minus'] = False

import seaborn as sns

# %%
music_list = os.listdir("/mnt/c/Users/sjt03/OneDrive/바탕 화면/유튜브/음악")
music_list
# Out:
# ['(여자)아이들 - LION.m4a',
#  '(여자)아이들 - MY BAG.m4a',
#  '(여자)아이들 - Nxde.m4a',
#  '(여자)아이들 - TOMBOY.m4a',
#  '(여자)아이들 - 덤디덤디.m4a',
#  '(여자)아이들 - 말리지 마.m4a',
#  '(여자)아이들 - 퀸카.m4a',
#  '(여자)아이들 - 클락션.m4a',
#  '10cm - 그라데이션.m4a',
#  '10cm - 서울의 잠 못 이루는 밤.m4a',
#  '10cm - 쓰담쓰담.m4a',
#  '10cm - 이 밤을 빌려 말해요.m4a',
#  "4 Non Blondes - What's Up.m4a",
#  '50 Cent - Candy Shop.m4a',
#  '50 Cent - In Da Club.m4a',
#  'ABBA - Waterloo.m4a',
#  'Abe Parker - Live, Laugh, Love.m4a',
#  'ACDC - Back In Black.m4a',
#  'ACDC - Highway to Hell.m4a',
#  'Adam Levine - Lost Stars.m4a',
#  'Adele - Skyfall.m4a',
#  'Against The Current - Legends Never Die.m4a',
#  'AJR - BANG!.m4a',
#  'AJR - Bummerland.m4a',
#  'AJR - Burn The House Down.m4a',
#  'AJR - OK Overture.m4a',
#  'AJR - Way Less Sad.m4a',
#  "AJR - World's Smallest Violin.m4a",
#  'Alice Merton - No Roots.m4a',
#  'Amy Winehouse - Back To Black.m4a',
#  'Andor - Forming Up_Unto Stone We Are.m4a',
#  'Andrew Bird - Sisyphus.m4a',
# ...

# %%
set([i.split(' - ')[0] for i in music_list])
# Out:
# {'(여자)아이들',
#  '10cm',
#  '4 Non Blondes',
#  '50 Cent',
#  'ABBA',
#  'ACDC',
#  'AJR',
#  'Abe Parker',
#  'Adam Levine',
#  'Adele',
#  'Against The Current',
#  'Alice Merton',
#  'Amy Winehouse',
#  'Andor',
#  'Andrew Bird',
#  'Andy Grammer',
#  'Armani White',
#  'Bee Gees',
#  'Benson Boone',
#  'Big Band',
#  'Bishop Briggs',
#  'Bobby Caldwell',
#  'Boney M.',
#  'Bonnie Tyler',
#  'Bruno Mars',
#  'Calvin Harris',
#  'Carrie Underwood',
#  'Charlie Puth',
#  'Cody Fry',
#  'Coolio',
#  'Creepy Nuts',
#  'DNCE',
#  'Damien Rice',
#  'Daniel Pemberton',
#  'Daryl Hall & John Oates',
#  'DeBarge',
#  'Des Rocs',
#  'Doctor Who',
#  'Doja Cat',
#  'Donna Summer',
#  'Dr. Dre',
#  'Dua Lipa',
#  'Earth, Wind & Fire',
#  'Elle King',
#  'Elton John',
#  'Em Beihold',
#  'Eminem',
#  'Eurythmics',
#  'Fall Out Boy',
#  'Fitz And The Tantrums',
#  'Fleetwood Mac',
#  'Franz Ferdinand',
#  'Funk Big Band',
#  'Game of Thrones',
#  'Ghost',
#  'Gin Wigmore',
#  'Ginger Root',
# ...

# %%
df_음악 = pd.DataFrame([i.replace('.m4a','').replace('.mp3','').split(' - ') for i in music_list], columns=['가수','제목'])
df_음악
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# File ~/miniconda3/envs/data/lib/python3.12/site-packages/pandas/core/internals/construction.py:939, in _finalize_columns_and_data(content, columns, dtype)
#     938 try:
# --> 939     columns = _validate_or_indexify_columns(contents, columns)
#     940 except AssertionError as err:
#     941     # GH#26429 do not raise user-facing AssertionError
#
# File ~/miniconda3/envs/data/lib/python3.12/site-packages/pandas/core/internals/construction.py:986, in _validate_or_indexify_columns(content, columns)
#     984 if not is_mi_list and len(columns) != len(content):  # pragma: no cover
#     985     # caller's responsibility to check for this...
# --> 986     raise AssertionError(
#     987         f"{len(columns)} columns passed, passed data had "
#     988         f"{len(content)} columns"
#     989     )
#     990 if is_mi_list:
# ...

# %%
Counter(df_음악['가수']).most_common(100)
# Out:
# [('Jason Mraz', 8),
#  ('지코', 8),
#  ('(여자)아이들', 7),
#  ('아이브', 7),
#  ('에스파', 7),
#  ('AJR', 6),
#  ('Muse', 6),
#  ('르세라핌', 6),
#  ('10cm', 4),
#  ('Imagine Dragons', 4),
#  ('NF', 4),
#  ('뉴진스', 4),
#  ('블랙핑크', 4),
#  ('선우정아', 4),
#  ('엔믹스', 4),
#  ('프로미스나인', 4),
#  ('Earth, Wind & Fire', 3),
#  ('Harry Styles', 3),
#  ('Samm Henshaw', 3),
#  ('Samuel Kim', 3),
#  ('송민호', 3),
#  ('이엑스아이디', 3),
#  ('트와이스', 3),
#  ('ACDC', 2),
#  ('Dua Lipa', 2),
#  ('Queen', 2),
#  ('X Ambassadors', 2),
#  ('걸스데이', 2),
#  ('데이브레이크', 2),
#  ('럼블피쉬', 2),
#  ('레인보우', 2),
#  ('리사', 2),
#  ('마마무', 2),
#  ('쇼미9', 2),
#  ('씨스타', 2),
#  ('아이묭', 2),
#  ('윌콕스', 2),
#  ('윤종신', 2),
#  ('장범준', 2),
#  ('체리필터', 2),
#  ('콜드', 2),
#  ('큐더블이알', 2),
#  ('태연', 2),
#  ('헤이즈', 2),
#  ('4 Non Blondes', 1),
#  ('ABBA', 1),
#  ('Abe Parker', 1),
#  ('Adam Levine', 1),
#  ('Adele', 1),
#  ('Against The Current', 1),
#  ('Alice Merton', 1),
#  ('Amy Winehouse', 1),
#  ('Andor', 1),
#  ('Andrew Bird', 1),
# ...
